# %%
from visualization.utils_visualization import automated_evaluation, ModelType, DatasetType

# %% [markdown]
# ### Numerical ECG

# %%
automated_evaluation(
        model_type=ModelType.CNN_NUMERICAL,
        dataset_type=DatasetType.ECG,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_numerical_ecg/epoch=epoch=16-val_loss=val_loss=0.014408.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_numerical_ecg/version_1/events.out.tfevents.1747073173.lab1F465O.4063.0
# /opt/anaconda3/lib/python3.12/site-packages/pytorch_lightning/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.5.1.post0, which is newer than your current Lightning version: v2.5.1
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'val_loss', 'epoch', 'train_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Numerical Harmonic

# %%
automated_evaluation(
        model_type=ModelType.CNN_NUMERICAL,
        dataset_type=DatasetType.HARMONIC,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_numerical_harmonic/epoch=epoch=46-val_loss=val_loss=0.030125.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_numerical_harmonic/version_0/events.out.tfevents.1746880400.lab1F465O.24923.1
# /opt/anaconda3/lib/python3.12/site-packages/pytorch_lightning/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.5.1.post0, which is newer than your current Lightning version: v2.5.1
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'val_loss', 'epoch', 'train_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Numerical OU

# %%
automated_evaluation(
        model_type=ModelType.CNN_NUMERICAL,
        dataset_type=DatasetType.OU,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_numerical_ou/epoch=epoch=11-val_loss=val_loss=0.176636.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_numerical_ou/version_0/events.out.tfevents.1746880654.lab1F465O.24923.2
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'val_loss', 'epoch', 'train_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Numerical SP500

# %%
automated_evaluation(
        model_type=ModelType.CNN_NUMERICAL,
        dataset_type=DatasetType.SP500,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_numerical_sp500/epoch=epoch=3-val_loss=val_loss=0.116131.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_numerical_sp500/version_0/events.out.tfevents.1746880883.lab1F465O.24923.3
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'val_loss', 'epoch', 'train_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Visual ECG

# %%
automated_evaluation(
        model_type=ModelType.CNN_VISUAL,
        dataset_type=DatasetType.ECG,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_visual_ecg/epoch=epoch=22-val_loss=val_loss=38.183380.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_visual_ecg/version_3/events.out.tfevents.1747039521.lab1F465O.5685.0
# Only one image to plot, converting axes to 2D array.
# /opt/anaconda3/lib/python3.12/site-packages/pytorch_lightning/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.5.1.post0, which is newer than your current Lightning version: v2.5.1
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'train_loss', 'epoch', 'val_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Visual Harmonic

# %%
automated_evaluation(
        model_type=ModelType.CNN_VISUAL,
        dataset_type=DatasetType.HARMONIC,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_visual_harmonic/epoch=epoch=59-val_loss=val_loss=45.634087.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_visual_harmonic/version_0/events.out.tfevents.1746886518.lab1F465O.24923.5
# Only one image to plot, converting axes to 2D array.
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'train_loss', 'epoch', 'val_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Visual OU

# %%
automated_evaluation(
        model_type=ModelType.CNN_VISUAL,
        dataset_type=DatasetType.OU,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_visual_ou/epoch=epoch=13-val_loss=val_loss=49.990959.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_visual_ou/version_0/events.out.tfevents.1746925744.lab1F465O.24923.6
# Only one image to plot, converting axes to 2D array.
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'train_loss', 'epoch', 'val_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %% [markdown]
# ### Visual SP500

# %%
automated_evaluation(
        model_type=ModelType.CNN_VISUAL,
        dataset_type=DatasetType.SP500,
        n_plots=1,
        all_predictions=True
    )
# Out:
# Latest checkpoint found: src/models/checkpoints/cnn_visual_sp500/epoch=epoch=55-val_loss=val_loss=38.501064.ckpt
# Most recent event file found: src/models/lightning_logs/cnn_visual_sp500/version_0/events.out.tfevents.1746933835.lab1F465O.24923.7
# Only one image to plot, converting axes to 2D array.
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['hp_metric', 'train_loss', 'epoch', 'val_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}
