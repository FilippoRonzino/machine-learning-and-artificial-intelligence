# %%
from visualization.utils_visualization import plot_predictions
from models.cnn_visual import (
    CNN_Autoencoder,
    ImageTimeSeriesDatasetSingleFolder,
    LossTrackerCallback,
)
import pytorch_lightning as pl

# %%
model = MyModel.load_from_checkpoint("src/models/checkpoints/cnn_visual/epoch=epoch=99-val_loss=val_loss=0.003508.ckpt")

# %%
dataset = ImageTimeSeriesDatasetSingleFolder(data_dir, prediction_percentage=0.25)
plot_predictions_visual_model(model, dataset)
